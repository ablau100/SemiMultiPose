# %%
# import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import cv2
import math
import torch
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import numpy as np
import matplotlib.colorbar as colorbar

import requests
from io import BytesIO
from PIL import Image
import numpy as np
from maskrcnn_benchmark.utils import cv2_util
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

from moviepy.editor import VideoFileClip

# this makes our figures bigger
pylab.rcParams['figure.figsize'] = 20*1.5, 12*1.5

from maskrcnn_benchmark.config import cfg
from maskrcnn_benchmark.structures.keypoint import keypoints_to_heat_map
from maskrcnn_benchmark.modeling.roi_heads.keypoint_head.loss import project_keypoints_to_heatmap
from predictor import COCODemo

# %%
def load(img_path):
    """
    Given an url of an image, downloads the image and
    returns a PIL image
    """
    
    pil_image = Image.open(img_path).convert("RGB")
    # convert to BGR format
    image = np.array(pil_image)[:, :, [2, 1, 0]]
    return image

def load_video(video_path,frame_id=[0]):
    """
    Given an url of an image, downloads the image and
    returns a PIL image
    """
    
    video_clip = VideoFileClip(video_path)
    if frame_id is None:
        nframes = int(video_clip.fps * video_clip.duration)
        frame_id = range(nframes)
    images = []
    for i in frame_id:
        image = video_clip.get_frame(i/video_clip.fps)
        # convert to BGR format
        image = np.array(image)[:, :, [2, 1, 0]]
        images += [image]
    video_clip.close()
    
    return images

def imshow(img):
    plt.gca().invert_yaxis()
    plt.imshow(img[:, :, [2, 1, 0]])
    plt.axis("off")
    
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
# define vectorized sigmoid
sigmoid_v = np.vectorize(sigmoid)

# num keypoints per animal, heatmap
def calculate_peaks(numparts, heatmap_avg):
    score = np.ones((numparts,)) * 0.000001
    all_peaks = []
    peak_counter = 0
    if len(score) < numparts:
        score = score[:numparts]
        print("score", score)
        ##logger.ERROR(‘Not enough scores provided for number of parts’)
        # return
    # threshold_detection = params[‘thre1’]
    # tic_localmax=time.time()
    for part in range(numparts):
        map_ori = heatmap_avg[part, :, :]
        map = map_ori
        map_left = np.zeros(map.shape)
        map_left[1:, :] = map[:-1, :]
        map_right = np.zeros(map.shape)
        map_right[:-1, :] = map[1:, :]
        map_up = np.zeros(map.shape)
        map_up[:, 1:] = map[:, :-1]
        map_down = np.zeros(map.shape)
        map_down[:, :-1] = map[:, 1:]
        #peaks_binary = np.logical_and(np.logical_and(np.logical_and(map >= map_left, map >= map_right),
                                                     #np.logical_and(map >= map_up, map >= map_down)), map > score[part])
        peaks_binary = (sigmoid_v(map_ori) > .2)
        #print("pb shap", np.shape(peaks_binary))
        peaks = list(zip(np.nonzero(peaks_binary)[1], np.nonzero(peaks_binary)[0]))  # note reverse
        peaks_with_score_and_id = [x + (map_ori[x[1], x[0]], i + peak_counter,) for i, x in
                                   enumerate(peaks)]  # if x[0]>0 and x[1]>0 ]
        all_peaks.append(peaks_with_score_and_id)
        peak_counter += len(peaks)
    return all_peaks

# %%
params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'jet',
    'axes.grid': False,
    'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize': 10, # fontsize for x and y labels (was 10)
    'axes.titlesize': 12,
    'font.size': 12, # was 10
    'legend.fontsize': 10, # was 10
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    #'text.usetex': True,
    'figure.figsize': [20, 12],
    'font.family': 'serif',
}
matplotlib.rcParams.update(params)

# %%
def overlay_keypoints(image, predictions):
        #keypoints = predictions.get_field("keypoints")
        kps = predictions#keypoints.keypoints
        scores = kps.new_ones((kps.size(0), kps.size(1)))
        kps = torch.cat((kps[:, :, 0:2], scores[:, :, None]), dim=2).numpy()
        for region in kps:
            kfun = BeeKeypoints
            image = vis_keypoints_others(
                    image,
                    region.transpose((1, 0)),
                    kp_thresh=0,
                    kfun=kfun)
                
        return image

# %%
import cv2
import torch
from torchvision import transforms as T

from maskrcnn_benchmark.modeling.detector import build_detection_model
from maskrcnn_benchmark.utils.checkpoint import DetectronCheckpointer
from maskrcnn_benchmark.structures.image_list import to_image_list
from maskrcnn_benchmark.modeling.roi_heads.mask_head.inference import Masker
from maskrcnn_benchmark import layers as L
from maskrcnn_benchmark.utils import cv2_util

import numpy as np
import matplotlib.pyplot as plt
from maskrcnn_benchmark.structures.keypoint import PersonKeypoints, BeeKeypoints, FlyKeypoints


def vis_keypoints_others(img, kps, kp_thresh=2, alpha=0.7, kfun=PersonKeypoints):
    """Visualizes keypoints (adapted from vis_one_image).
    kps has shape (4, #keypoints) where 4 rows are (x, y, logit, prob).
    """
    img = img.copy()
    dataset_keypoints = kfun.NAMES
    kp_lines = kfun.CONNECTIONS

    # Convert from plt 0-1 RGBA colors to 0-255 BGR colors for opencv.
    cmap = plt.get_cmap('rainbow')
    colors = [cmap(i) for i in np.linspace(0, 1, len(kp_lines) + 2)]
    colors = [(c[2] * 255, c[1] * 255, c[0] * 255) for c in colors]

    # Perform the drawing on a copy of the image, to allow for blending.
    kp_mask = np.copy(img)
    
    # Draw the keypoints.
    for l in [0]:#range(len(kp_lines)):
        i1 = kp_lines[l][0]
        i2 = kp_lines[l][1]
        p1 = kps[0, i1], kps[1, i1]
        p2 = kps[0, i2], kps[1, i2]
        #if kps[2, i1] > kp_thresh and kps[2, i2] > kp_thresh:
         #   cv2.line(
          #      kp_mask, p1, p2,
           #     color=colors[l], thickness=2, lineType=cv2.LINE_AA)
        if kps[2, i1] > kp_thresh:
            cv2.circle(
                kp_mask, p1,
                radius=16, color=colors[l], thickness=-1, lineType=cv2.LINE_AA)
        #if kps[2, i2] > kp_thresh:
         #   cv2.circle(
          #      kp_mask, p2,
           #     radius=16, color=colors[l], thickness=-1, lineType=cv2.LINE_AA)

    # Blend the keypoints.
    return cv2.addWeighted(img, 1.0 - alpha, kp_mask, alpha, 0)

def bounding_box(points):
    x_coordinates, y_coordinates = zip(*points)
    return [min(x_coordinates), min(y_coordinates), max(x_coordinates), max(y_coordinates)]

def get_centroid(coord):
    return [(coord[0]+coord[2])/2, (coord[1]+coord[3])/2]

def get_dist(p1, p2):
    dist = math.hypot(p2[0] - p1[0], p2[1] - p1[1])
    return dist

# %%
#test_file = 'bee_test.png'
#image = load(test_file)
base = "../tools/datasets/bee/validation/"
#base = "../tools/datasets/bee/train/"
base_val = "../tools/datasets/bee/annotations/validation.json"
#base_val = "../tools/datasets/bee/annotations/train_bee_annotations2018_nondup.json"

import json
with open(base_val) as f:
    data_an = json.load(f)
#print(data_an["annotations"][0])

test_files = []
for p in data_an['images'][:]:
    test_files.append(str(p['file_name']))

print(test_files)
print(len(test_files))
test_images = []
for file in test_files:
    test_images.append(load(base + file))
# Out:
# ['000000051501.jpg', '000000051602.jpg', '000000051656.jpg', '000000051770.jpg', '000000052209.jpg', '000000052239.jpg', '000000052248.jpg', '000000052271.jpg', '000000052328.jpg', '000000052361.jpg', '000000052413.jpg', '000000052563.jpg', '000000052583.jpg', '000000052587.jpg', '000000052738.jpg', '000000052799.jpg', '000000052861.jpg', '000000053184.jpg', '000000053247.jpg', '000000053341.jpg', '000000053573.jpg', '000000053614.jpg', '000000053776.jpg', '000000053802.jpg', '000000053827.jpg', '000000053842.jpg', '000000053857.jpg', '000000053866.jpg', '000000053890.jpg', '000000053916.jpg']
# 30

# %%
# saver = {"standard":[{'v1':s_v1}, {'v2':s_v2}, {'v3':s_v3}],
# "combined":[{'v1':c_v1}, {'v2':c_v2}, {'v3':c_v3}],
# "unlabeled":[{'v1':u_v1}, {'v2':u_v2}, {'v3':u_v3}]}

# %%
import pickle
with open('all_5_test_boxes.pkl', 'rb') as f:
    r5 = pickle.load(f)

# %%
print((r5['standard'][0]['v1'][0][10]))
# Out:
# BoxList(num_boxes=16, image_width=2560, image_height=1440, mode=xyxy)

# %%
from maskrcnn_benchmark.data.datasets.evaluation import evaluate
from maskrcnn_benchmark.data import make_data_loader
from maskrcnn_benchmark.config import cfg
from maskrcnn_benchmark.structures.keypoint import keypoints_to_heat_map
from maskrcnn_benchmark.modeling.roi_heads.keypoint_head.loss import project_keypoints_to_heatmap
from predictor import COCODemo


config_file = "/home/bsb2144/directpose/configs/fcos/fcos_kps_ms_training_R_50_FPN_1x.yaml"

cfg.merge_from_file("/home/bsb2144/directpose/configs/fcos/fcos_kps_ms_training_R_50_FPN_1x.yaml")
cfg.merge_from_list(['DATALOADER.NUM_WORKERS', '2', \
                     'DATATYPE', 'bee', \
                     'OUTPUT_DIR', 'training_dir/fcos_kps_ms_training_R_50_FPN_1x_bee1', \
                     'MODEL.WEIGHT', '/home/bsb2144/directpose/tools/training_dir/fcos_kps_ms_training_R_50_FPN_1x_bee/mode.pth',\
                     'DATASETS.TEST', "('bee_val_cocostyle',)",\
                     'DATASETS.TRAIN', "('bee_train_cocostyle', )",\
                    ])

ds = make_data_loader(cfg,poop=True)

#res = evaluate()
# Out:
# When using more than one image per GPU you may encounter an out-of-memory (OOM) error if your GPU does not have sufficient memory. If this happens, you can reduce SOLVER.IMS_PER_BATCH (for training) or TEST.IMS_PER_BATCH (for inference). For training, you must also adjust the learning rate and schedule length according to the linear scaling rule. See for example: https://github.com/facebookresearch/Detectron/blob/master/configs/getting_started/tutorial_1gpu_e2e_faster_rcnn_R-50-FPN.yaml#L14
# train san check: True
# im p gpu:  16
# DATA Path;  ('bee_val_cocostyle',)
# name?
# /home/bsb2144/directpose/tools/datasets/bee/annotations/validation.json
# datasets/bee/validation
# BeeKeypoints
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# len ids pre  30

# %%
s_5= [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

c_5 = [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

u_5 = [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

s_25= [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

c_25 = [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

u_25 = [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

s_135= [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

c_135 = [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

u_135 = [[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]

# %%
data_numbers = ['all_5_test_boxes.pkl','all_25_test_boxes.pkl','all_135_test_boxes.pkl']
iters = [range(0,15),range(0,13),range(0,10)]
versions = ["v1",'v2','v3']
losses = ['standard','combined','unlabeled']

i=1
with open(data_numbers[i], 'rb') as f:
    rr = pickle.load(f)

for l,loss in enumerate(losses):
    dic = rr[loss]
    for i,v in enumerate(versions):
        for it in iters[l]:
            #print(loss,v,it)
            #rr[loss][i][v][it]
            res = evaluate(ds, rr[loss][i][v][it], 'pathhe')[0]
            ap = res.results['keypoints']['AP']
            ap_50 = res.results['keypoints']['AP50']
            ap_75 = res.results['keypoints']['AP75']
            ap2 = res.results['keypoints']['APl']
            if l == 0:
                s_5[0][i].append(ap)
                s_5[1][i].append(ap_50)
                s_5[2][i].append(ap_75)
                s_5[3][i].append(ap2)
            elif l == 1:
                c_5[0][i].append(ap)
                c_5[1][i].append(ap_50)
                c_5[2][i].append(ap_75)
                c_5[3][i].append(ap2)
            elif l == 2:
                u_5[0][i].append(ap)
                u_5[1][i].append(ap_50)
                u_5[2][i].append(ap_75)
                u_5[3][i].append(ap2)
# Out:
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c474761d0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.38s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.184
# Loading and preparing results...
# DONE (t=0.11s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c438>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=1.04s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.448
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.254
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748cd68>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.87s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.593
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.350
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47482a20>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.68s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.591
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.373
# Loading and preparing results...
# DONE (t=0.07s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c5c0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.80s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.439
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c8d0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.70s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.697
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.518
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.518
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c474824a8>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.90s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.369
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.698
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.375
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.513
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c630>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.88s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.711
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.520
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c550>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.75s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.520
# Loading and preparing results...
# DONE (t=0.07s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47482978>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.93s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.726
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.826
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.522
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47497a90>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.89s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.711
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.517
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748cac8>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.82s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.703
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.398
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.521
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c400>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.83s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.726
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.390
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.526
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c474824a8>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.84s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.718
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.521
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c474977f0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.88s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.738
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.519
# Loading and preparing results...
# DONE (t=0.08s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c390>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.81s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.120
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.271
# Loading and preparing results...
# DONE (t=0.08s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c940>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.92s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.497
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.288
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c0f0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.76s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.614
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.313
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.408
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c2b0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.99s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.699
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.423
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.796
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.423
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746ca58>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.84s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.595
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.438
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.438
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c400>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.96s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.518
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.796
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.518
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c588>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.77s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.695
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.388
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.520
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746cb70>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.59s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.675
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.516
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4749eac8>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.517
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c710>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.59s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.376
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.518
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.518
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47497ac8>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.56s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.388
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.527
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47482940>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.57s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.722
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.510
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c1d0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.62s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.725
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.514
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746cfd0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.59s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.711
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.514
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c474978d0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.57s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.732
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.387
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.523
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748cd30>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.44s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.198
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c474829e8>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.244
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.244
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47497390>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.55s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.257
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.592
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.257
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.438
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.405
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47482da0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.58s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.718
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.408
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c0f0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.580
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.422
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748cd68>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.58s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.388
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.524
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748cb00>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.57s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.709
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.529
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c438>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.57s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.698
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.421
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.390
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.519
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4748c208>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.699
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.422
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.391
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.525
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c47482be0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.59s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.710
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.395
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.527
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4749ee48>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.710
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.393
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.826
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.529
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# coco_gt <pycocotools.coco.COCO object at 0x2b4c46215fd0>
# coco_dt <pycocotools.coco.COCO object at 0x2b4c4746c6a0>
# iou_type keypoints
# datatype pup
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.62s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.701
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.526
# Loading and preparing results...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-36c2671ff695> in <module>
#      14             #print(loss,v,it)
#      15             #rr[loss][i][v][it]
# ---> 16             res = evaluate(ds, rr[loss][i][v][it], 'pathhe')[0]
#      17             ap = res.results['keypoints']['AP']
#      18             ap_50 = res.results['keypoints']['AP50']
#
# /share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/evaluation/__init__.py in evaluate(dataset, predictions, output_folder, **kwargs)
#      20     )
#      21     if isinstance(dataset, datasets.COCODataset):
# ---> 22         return coco_evaluation(**args)
#      23     elif isinstance(dataset, datasets.PascalVOCDataset):
#      24         return voc_evaluation(**args)
#
# /share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/evaluation/coco/__init__.py in coco_evaluation(dataset, predictions, output_folder, box_only, iou_types, expected_results, expected_results_sigma_tol, datatype)
#      20         expected_results=expected_results,
#      21         expected_results_sigma_tol=expected_results_sigma_tol,
# ---> 22         datatype=datatype,
#      23     )
#
# /share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/evaluation/coco/coco_eval.py in do_coco_evaluation(dataset, predictions, box_only, output_folder, iou_types, expected_results, expected_results_sigma_tol, datatype)
#      59                 file_path = os.path.join(output_folder, iou_type + ".json")
#      60             res = evaluate_predictions_on_coco(
# ---> 61                 dataset.coco, coco_results[iou_type], file_path, iou_type, datatype
#      62             )
#      63             results.update(res)
#
# /share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/evaluation/coco/coco_eval.py in evaluate_predictions_on_coco(coco_gt, coco_results, json_result_file, iou_type, datatype)
#     321     from pycocotools.cocoeval import COCOeval
#     322
# --> 323     coco_dt = coco_gt.loadRes(str(json_result_file)) if coco_results else COCO()
#     324
#     325     # coco_dt = coco_gt.loadRes(coco_results)
#
# ~/miniconda3/envs/directpose/lib/python3.7/site-packages/pycocotools-2.0-py3.7-linux-x86_64.egg/pycocotools/coco.py in loadRes(self, resFile)
#     315         tic = time.time()
#     316         if type(resFile) == str or (PYTHON_VERSION == 2 and type(resFile) == unicode):
# --> 317             anns = json.load(open(resFile))
#     318         elif type(resFile) == np.ndarray:
#     319             anns = self.loadNumpyAnnotations(resFile)
#
# ~/miniconda3/envs/directpose/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# ~/miniconda3/envs/directpose/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/miniconda3/envs/directpose/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 137902 (char 137901)

# %%
print(res.results['keypoints'])

# %%
sa1 = []
for w1,w2,w3 in zip(s_5[0][0],s_5[0][1],s_5[0][2]):
    sa1.append((w1+w2+w3)/3)
ca1 = []
for w1,w2,w3 in zip(c_5[0][0],c_5[0][1],c_5[0][2]):
    ca1.append((w1+w2+w3)/3)
va1 = []
for w1,w2,w3 in zip(u_5[0][0],u_5[0][1],u_5[0][2]):
    va1.append((w1+w2+w3)/3)
    
sa2 = []
for w1,w2,w3 in zip(s_5[1][0],s_5[1][1],s_5[1][2]):
    sa2.append((w1+w2+w3)/3)
ca2 = []
for w1,w2,w3 in zip(c_5[1][0],c_5[1][1],c_5[1][2]):
    ca2.append((w1+w2+w3)/3)
va2 = []
for w1,w2,w3 in zip(u_5[1][0],u_5[1][1],u_5[1][2]):
    va2.append((w1+w2+w3)/3)
    
sa3 = []
for w1,w2,w3 in zip(s_5[2][0],s_5[2][1],s_5[2][2]):
    sa3.append((w1+w2+w3)/3)
ca3 = []
for w1,w2,w3 in zip(c_5[2][0],c_5[2][1],c_5[2][2]):
    ca3.append((w1+w2+w3)/3)
va3 = []
for w1,w2,w3 in zip(u_5[2][0],u_5[2][1],u_5[2][2]):
    va3.append((w1+w2+w3)/3)
    
sa4 = []
for w1,w2,w3 in zip(s_5[3][0],s_5[3][1],s_5[3][2]):
    sa4.append((w1+w2+w3)/3)
ca4 = []
for w1,w2,w3 in zip(c_5[3][0],c_5[3][1],c_5[3][2]):
    ca4.append((w1+w2+w3)/3)
va4 = []
for w1,w2,w3 in zip(u_5[3][0],u_5[3][1],u_5[3][2]):
    va4.append((w1+w2+w3)/3)

# %%
s_e = []
c_e = []
u_e = []
#print(c1)
for w1,w2,w3 in zip(s_5[3][0],s_5[3][1],s_5[3][2]):
    s_e.append(np.std([w1,w2,w3])/np.sqrt(3))
    
for w1,w2,w3 in zip(c_5[3][0],c_5[3][1],c_5[3][2]):
    c_e.append(np.std([w1,w2,w3])/np.sqrt(3))
    
for w1,w2,w3 in zip(u_5[3][0],u_5[3][1],u_5[3][2]):
    u_e.append(np.std([w1,w2,w3])/np.sqrt(3))

# %%
SMALL_SIZE = 11
MEDIUM_SIZE = 15
BIGGER_SIZE = 20
plt.rcParams.update({'font.size': 22})
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=40)  # fontsize of the figure title
#plt.rc('font', 8)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
it_c = range(3000,15001,1000)
it1 = range(3000,15001,1000)
itu = range(6000,15001,1000)
ite = range(6000,14001,1000)
ita = range(1000,15001,1000)
fig, axes = plt.subplots(1,1,figsize=(16,8))
ax = axes
plt.xlabel("iteration")
plt.ylabel("mAP")
fig.suptitle("mAP: trained on 25 labeled images ",fontsize = 22)
colors = ['r','b','y','g']

#plt.plot(ita, sa1, '-o', c='grey', label="standard ap1")
#plt.plot(ita, sa2, '-o', c='grey', label="standard")
#plt.plot(ita, sa3, '-o', c='brown', label="standard ap3")
plt.plot(ita, sa4, '-o', c='grey', label="standard")
plt.fill_between(ita, np.array(sa4)-np.array(s_e), np.array(sa4)+np.array(s_e),alpha = .2,color='grey')


#plt.plot(it1, ca1, '-o', c='blue', label="combined ap1")
#plt.plot(it1, ca2, '-o', c='blue', label="combined")
#plt.plot(it1, ca3, '-o', c='green', label="combined ap3")
plt.plot(it1, ca4, '-o', c='blue', label="combined")
plt.fill_between(it1, np.array(ca4)-np.array(c_e), np.array(ca4)+np.array(c_e),alpha = .2,color='blue')


#plt.plot(itu, va1, '-o', c='orange', label="unlabeled ap1")
#plt.plot(itu, va2, '-o', c='orange', label="unlabeled")
#plt.plot(itu, va3, '-o', c='pink', label="unlabeled ap3")
plt.plot(itu, va4, '-o', c='orange', label="unlabeled")
plt.fill_between(itu, np.array(va4)-np.array(u_e), np.array(va4)+np.array(u_e),alpha = .2,color='orange')


#plt.plot(ita, bu[0:15], c='red', label="Sleap bottom up")
#plt.plot(ita, td[0:15], c='green', label="Sleap top down")
#ax.set_ylim(top = .9,bottom = .7)
fig.legend(loc='upper left')
fig.savefig("ap_25" +'.pdf')
plt.show()

# %%
f_aps = {"standard":{'va':s_25},
"combined":{'va':c_25},
"unlabeled":{'va':u_25}}

# %%
#with open('aps_25.pkl', 'wb') as f:
 #   pickle.dump(f_aps, f)

# %%
print(len(f_aps['standard']['va']))

# %%
with open('all_5_test_boxes.pkl', 'rb') as f:
    ap25 = pickle.load(f)
with open('all_25_test_boxes.pkl', 'rb') as f:
    ap5 = pickle.load(f)

# %%
print(ap25['standard'][0]['v1'][0][0])

# %%
print(ap5['standard'][0]['v1'][0][0])

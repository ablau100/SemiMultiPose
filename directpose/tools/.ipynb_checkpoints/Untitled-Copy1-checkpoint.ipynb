# %%
# !python nc_250_10.py "combined" "250" "0" ".1"
# Out:
# before
# nc_250_10.py
# combined
# alp:  .1
# loss type:  combined
# .1
# 250
# after
# 2021-04-14 20:58:31,340 maskrcnn_benchmark INFO: Using 1 GPUs
# 2021-04-14 20:58:31,340 maskrcnn_benchmark INFO: AMP_VERBOSE: False
# DATALOADER:
#   ASPECT_RATIO_GROUPING: True
#   NUM_WORKERS: 2
#   SIZE_DIVISIBILITY: 32
# DATASETS:
#   TEST: ('keypoints_coco_2014_minival',)
#   TRAIN: ('bee_train_cocostyle', 'bee_train_cocostyle')
# DATATYPE: bee
# DTYPE: float32
# INPUT:
#   BRIGHTNESS: 0.0
#   CONTRAST: 0.0
#   CROP_SIZE: 800
#   FLIP_PROB_TRAIN: 0.5
#   HUE: 0.0
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 2666
#   MIN_SIZE_RANGE_TRAIN: (480, 1600)
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
#   PIXEL_MEAN: [102.9801, 115.9465, 122.7717]
#   PIXEL_STD: [1.0, 1.0, 1.0]
#   SATURATION: 0.0
#   TO_BGR255: True
# MODEL:
#   ANIMAL_ON: False
#   BACKBONE:
#     CONV_BODY: R-50-FPN-RETINANET
#     FREEZE_CONV_BODY_AT: 2
#     USE_GN: False
#   CENTROID: False
# ...

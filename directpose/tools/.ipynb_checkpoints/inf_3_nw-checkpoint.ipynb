# %%
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import cv2
import os
import math
import torch
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import numpy as np
import matplotlib.colorbar as colorbar

import requests
from io import BytesIO
from PIL import Image
import numpy as np
from maskrcnn_benchmark.utils import cv2_util
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

from moviepy.editor import VideoFileClip

# this makes our figures bigger
pylab.rcParams['figure.figsize'] = 20*1.5, 12*1.5

from maskrcnn_benchmark.config import cfg
from maskrcnn_benchmark.structures.keypoint import keypoints_to_heat_map
from maskrcnn_benchmark.modeling.roi_heads.keypoint_head.loss import project_keypoints_to_heatmap
from demo.predictor import COCODemo
from torchvision import transforms as T

from maskrcnn_benchmark.modeling.detector import build_detection_model
from maskrcnn_benchmark.utils.checkpoint import DetectronCheckpointer
from maskrcnn_benchmark.structures.image_list import to_image_list
from maskrcnn_benchmark.modeling.roi_heads.mask_head.inference import Masker
from maskrcnn_benchmark import layers as L
from maskrcnn_benchmark.utils import cv2_util

from maskrcnn_benchmark.structures.keypoint import PersonKeypoints, BeeKeypoints, FlyKeypoints

# %%
def load(img_path):
    """
    Given an url of an image, downloads the image and
    returns a PIL image
    """
    
    pil_image = Image.open(img_path).convert("RGB")
    # convert to BGR format
    image = np.array(pil_image)[:, :, [2, 1, 0]]
    return image

def load_video(video_path,frame_id=[0]):
    """
    Given an url of an image, downloads the image and
    returns a PIL image
    """
    
    video_clip = VideoFileClip(video_path)
    if frame_id is None:
        nframes = int(video_clip.fps * video_clip.duration)
        frame_id = range(nframes)
    images = []
    for i in frame_id:
        image = video_clip.get_frame(i/video_clip.fps)
        # convert to BGR format
        image = np.array(image)[:, :, [2, 1, 0]]
        images += [image]
    video_clip.close()
    
    return images

def imshow(img):
    plt.imshow(img[:, :, [2, 1, 0]])
    plt.axis("off")
    
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
# define vectorized sigmoid
sigmoid_v = np.vectorize(sigmoid)

# num keypoints per animal, heatmap
def calculate_peaks(numparts, heatmap_avg):
    score = np.ones((numparts,)) * 0.000001
    all_peaks = []
    peak_counter = 0
    if len(score) < numparts:
        score = score[:numparts]
        print("score", score)
        ##logger.ERROR(‘Not enough scores provided for number of parts’)
        # return
    # threshold_detection = params[‘thre1’]
    # tic_localmax=time.time()
    for part in range(numparts):
        map_ori = heatmap_avg[part, :, :]
        map = map_ori
        map_left = np.zeros(map.shape)
        map_left[1:, :] = map[:-1, :]
        map_right = np.zeros(map.shape)
        map_right[:-1, :] = map[1:, :]
        map_up = np.zeros(map.shape)
        map_up[:, 1:] = map[:, :-1]
        map_down = np.zeros(map.shape)
        map_down[:, :-1] = map[:, 1:]
        #peaks_binary = np.logical_and(np.logical_and(np.logical_and(map >= map_left, map >= map_right),
                                                     #np.logical_and(map >= map_up, map >= map_down)), map > score[part])
        peaks_binary = (sigmoid_v(map_ori) > .2)
        print("pb shap", np.shape(peaks_binary))
        peaks = list(zip(np.nonzero(peaks_binary)[1], np.nonzero(peaks_binary)[0]))  # note reverse
        peaks_with_score_and_id = [x + (map_ori[x[1], x[0]], i + peak_counter,) for i, x in
                                   enumerate(peaks)]  # if x[0]>0 and x[1]>0 ]
        all_peaks.append(peaks_with_score_and_id)
        peak_counter += len(peaks)
    return all_peaks

def load_images_from_folder(folder):
    images = []
    file_names = []
    for filename in os.listdir(folder):
        if ".jpg" in filename:
            img = load(os.path.join(folder,filename))
            if img is not None:
                images.append(img)
                file_names.append(filename)
    return images, file_names

# %%
params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'jet',
    'axes.grid': False,
    'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize': 10, # fontsize for x and y labels (was 10)
    'axes.titlesize': 12,
    'font.size': 12, # was 10
    'legend.fontsize': 10, # was 10
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    #'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
matplotlib.rcParams.update(params)

# %%
def overlay_keypoints(image, predictions):
        #keypoints = predictions.get_field("keypoints")
        kps = predictions#keypoints.keypoints
        scores = kps.new_ones((kps.size(0), kps.size(1)))
        kps = torch.cat((kps[:, :, 0:2], scores[:, :, None]), dim=2).numpy()
        for region in kps:
            kfun = BeeKeypoints
            image = vis_keypoints_others(
                    image,
                    region.transpose((1, 0)),
                    kp_thresh=0,
                    kfun=kfun)
                
        return image

# %%
def vis_keypoints_others(img, kps, kp_thresh=2, alpha=0.7, kfun=PersonKeypoints):
    """Visualizes keypoints (adapted from vis_one_image).
    kps has shape (4, #keypoints) where 4 rows are (x, y, logit, prob).
    """
    img = img.copy()
    dataset_keypoints = kfun.NAMES
    kp_lines = kfun.CONNECTIONS

    # Convert from plt 0-1 RGBA colors to 0-255 BGR colors for opencv.
    cmap = plt.get_cmap('rainbow')
    colors = [cmap(i) for i in np.linspace(0, 1, len(kp_lines) + 2)]
    colors = [(c[2] * 255, c[1] * 255, c[0] * 255) for c in colors]

    # Perform the drawing on a copy of the image, to allow for blending.
    kp_mask = np.copy(img)
    
    # Draw the keypoints.
    for l in [0]:#range(len(kp_lines)):
        i1 = kp_lines[l][0]
        i2 = kp_lines[l][1]
        p1 = kps[0, i1], kps[1, i1]
        p2 = kps[0, i2], kps[1, i2]
        #if kps[2, i1] > kp_thresh and kps[2, i2] > kp_thresh:
         #   cv2.line(
          #      kp_mask, p1, p2,
           #     color=colors[l], thickness=2, lineType=cv2.LINE_AA)
        if kps[2, i1] > kp_thresh:
            cv2.circle(
                kp_mask, p1,
                radius=16, color=colors[l], thickness=-1, lineType=cv2.LINE_AA)
        #if kps[2, i2] > kp_thresh:
         #   cv2.circle(
          #      kp_mask, p2,
           #     radius=16, color=colors[l], thickness=-1, lineType=cv2.LINE_AA)

    # Blend the keypoints.
    return cv2.addWeighted(img, 1.0 - alpha, kp_mask, alpha, 0)

# %%
#test_file = 'test_bee_2.png'
#image = load(test_file)

# %%
folder = "datasets/bee/train/"
test_images, test_image_files = load_images_from_folder(folder)

# %%
#need to get targets from images
from maskrcnn_benchmark.data import make_data_loader
from maskrcnn_benchmark.config import cfg
config_file = "/home/bsb2144/directpose/configs/fcos/fcos_kps_ms_training_R_50_FPN_1x.yaml"
cfg.merge_from_file(config_file)
cfg.merge_from_list(['DATALOADER.NUM_WORKERS', 2, \
                     'DATATYPE', 'bee', \
        'OUTPUT_DIR', 'training_dir/250/l_standard/fcos_kps_ms_training_R_50_FPN_1x_bee', \
        'SOLVER.KPS_GRAD_MULT', 10.0, \
        'SOLVER.MAX_GRAD_NORM', 5.0, \
        'SOLVER.POWER', 1.0, \
        'INPUT.CROP_SIZE', 800, \
        'INPUT.MIN_SIZE_RANGE_TRAIN', '(480, 1600)', \
        'INPUT.MAX_SIZE_TRAIN', 2666, \
        'MODEL.WEIGHT', 'training_dir/250/standard/fcos_kps_ms_training_R_50_FPN_1x_bee/model_final.pth', \
        'MODEL.RPN.BATCH_SIZE_PER_IMAGE', 1,\
        'MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE', 1,\
        'SOLVER.IMS_PER_BATCH', 3, \
        'SOLVER.MAX_ITER', 180000, \
        'MODEL.HEATMAPS_LOSS_WEIGHT', 4.0, \
        'DATASETS.TRAIN', "('bee_train_cocostyle', 'bee_train_cocostyle')"
        ])

data_loader, dataset = make_data_loader(
        cfg,
        is_train=True,
        is_distributed=False,
        start_iter=0,
    )
# Out:
# hoo
# DATA Path;  ('bee_train_cocostyle', 'bee_train_cocostyle')
# data? : {'factory': 'COCODataset', 'args': {'root': 'datasets/bee/train', 'ann_file': 'datasets/bee/annotations/train_bee_annotations2018.json', 'kfun': 'BeeKeypoints'}}
# fact:  <class 'maskrcnn_benchmark.data.datasets.coco.COCODataset'>
# D:  <module 'maskrcnn_benchmark.data.datasets' from '/share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/__init__.py'>
# args:  {'root': 'datasets/bee/train', 'ann_file': 'datasets/bee/annotations/train_bee_annotations2018.json', 'kfun': 'BeeKeypoints', 'remove_images_without_annotations': True, 'transforms': Compose(
#     <maskrcnn_benchmark.data.transforms.transforms.ColorJitter object at 0x2b03fcaba908>
#     <maskrcnn_benchmark.data.transforms.transforms.Resize object at 0x2b03fcaba780>
#     <maskrcnn_benchmark.data.transforms.transforms.RandomCrop object at 0x2b03fcaba4a8>
#     <maskrcnn_benchmark.data.transforms.transforms.RandomHorizontalFlip object at 0x2b03fcaba6a0>
#     <maskrcnn_benchmark.data.transforms.transforms.ToTensor object at 0x2b03fcaba828>
#     <maskrcnn_benchmark.data.transforms.transforms.Normalize object at 0x2b03fcaba6d8>
# )}
# name?
# datasets/bee/annotations/train_bee_annotations2018.json
# datasets/bee/train
# BeeKeypoints
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
062227200, 93: 17062228400, 94: 17062229600, 95: 17062230800, 96: 17062232000, 97: 17062232195, 98: 17062233200, 99: 17062234400, 100: 17062235600, 101: 17062236800, 102: 17062238000, 103: 17062238291, 104: 17062239200, 105: 17062240400, 106: 17062241600, 107: 17062242800, 108: 17062244000, 109: 17062244925, 110: 17062245200, 111: 17062246400, 112: 17062248800, 113: 17062251200, 114: 17062252400, 115: 17062253586, 116: 17062253600, 117: 17062254800, 118: 17062257200, 119: 17062258400, 120: 17062259600, 121: 17062260800, 122: 17062310800, 123: 17062312000, 124: 17062313200, 125: 17062314400, 126: 17062315600, 127: 17062316800, 128: 17062318000, 129: 17062321600, 130: 17062322800, 131: 17062324000, 132: 17062325200, 133: 17062326400, 134: 17062327600}
# data? : {'factory': 'COCODataset', 'args': {'root': 'datasets/bee/train', 'ann_file': 'datasets/bee/annotations/train_bee_annotations2018.json', 'kfun': 'BeeKeypoints'}}
# fact:  <class 'maskrcnn_benchmark.data.datasets.coco.COCODataset'>
# D:  <module 'maskrcnn_benchmark.data.datasets' from '/share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/__init__.py'>
# args:  {'root': 'datasets/bee/train', 'ann_file': 'datasets/bee/annotations/train_bee_annotations2018.json', 'kfun': 'BeeKeypoints', 'remove_images_without_annotations': True, 'transforms': Compose(
#     <maskrcnn_benchmark.data.transforms.transforms.ColorJitter object at 0x2b03fcaba908>
#     <maskrcnn_benchmark.data.transforms.transforms.Resize object at 0x2b03fcaba780>
#     <maskrcnn_benchmark.data.transforms.transforms.RandomCrop object at 0x2b03fcaba4a8>
#     <maskrcnn_benchmark.data.transforms.transforms.RandomHorizontalFlip object at 0x2b03fcaba6a0>
#     <maskrcnn_benchmark.data.transforms.transforms.ToTensor object at 0x2b03fcaba828>
#     <maskrcnn_benchmark.data.transforms.transforms.Normalize object at 0x2b03fcaba6d8>
# )}
# name?
# datasets/bee/annotations/train_bee_annotations2018.json
# datasets/bee/train
# BeeKeypoints
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# ids: : [1706210, 1706220, 1706230, 1706211200, 1706211912, 1706212400, 1706212912, 1706213912, 1706214912, 1706216112, 1706217312, 1706218312, 1706219512, 1706221200, 1706222400, 1706223600, 1706224800, 1706226000, 1706227200, 1706228200, 1706229244, 1706229257, 1706229400, 1706231200, 1706232200, 1706234600, 1706235800, 1706237000, 1706238400, 1706239600, 1706271399, 1706273385, 1706273792, 1706274698, 1706274970, 1706275985, 1706276300, 1706276301, 17062110512, 17062111312, 17062112512, 17062114312, 17062115512, 17062117112, 17062120464, 17062121664, 17062123264, 17062124664, 17062125864, 17062127064, 17062128464, 17062129664, 17062130864, 17062132064, 17062133264, 17062134464, 17062135864, 17062137064, 17062138264, 17062139464, 17062140664, 17062142064, 17062143264, 17062144464, 17062147868, 17062149068, 17062150068, 17062151268, 17062152268, 17062153468, 17062155068, 17062156268, 17062157068, 17062158468, 17062159468, 17062160535, 17062161135, 17062162535, 17062210600, 17062211800, 17062213000, 17062214200
# ds:  <maskrcnn_benchmark.data.datasets.concat_dataset.ConcatDataset object at 0x2b03fcabaa90>
# len:  270

# %%
coco_demo = COCODemo(
                cfg,
                min_image_size=800,
                confidence_threshold=0.2,
            )

# %%
#print(dataset.id_to_img_map)
for i, d in enumerate(data_loader): # or i, image in enumerate(dataset)
    print(d)
    print("id: ", dataset.get_img_info(i)["file_name"] )
    print("next")
# Out:
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781f60>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (0,))
# id:  000001706210.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (1,))
# id:  000001706220.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7952e8>, (BoxList(num_boxes=48, image_width=1333, image_height=750, mode=xyxy),), (2,))
# id:  000001706230.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cc88>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (3,))
# id:  001706211200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8ac8>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (4,))
# id:  001706211912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (5,))
# id:  001706212400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558d30>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (6,))
# id:  001706212912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1860>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (7,))
# id:  001706213912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d898>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (8,))
# id:  001706214912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c208>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (9,))
# id:  001706216112.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c5c0>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (10,))
# id:  001706217312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781f60>, (BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy),), (11,))
# id:  001706218312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b80f0>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (12,))
# id:  001706219512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7956a0>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (13,))
# id:  001706221200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795cc0>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (14,))
# id:  001706222400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c780>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (15,))
# id:  001706223600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6cc0>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (16,))
# id:  001706224800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b89e8>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (17,))
# id:  001706226000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d7f0>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (18,))
# id:  001706227200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6a58>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (19,))
# id:  001706228200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6978>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (20,))
# id:  001706229244.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781e10>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (21,))
# id:  001706229257.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781eb8>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (22,))
# id:  001706229400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c208>, (BoxList(num_boxes=46, image_width=1333, image_height=750, mode=xyxy),), (23,))
# id:  001706231200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8390>, (BoxList(num_boxes=48, image_width=1333, image_height=750, mode=xyxy),), (24,))
# id:  001706232200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=40, image_width=1333, image_height=750, mode=xyxy),), (25,))
# id:  001706234600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0940>, (BoxList(num_boxes=40, image_width=1333, image_height=750, mode=xyxy),), (26,))
# id:  001706235800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795198>, (BoxList(num_boxes=56, image_width=1333, image_height=750, mode=xyxy),), (27,))
# id:  001706237000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1f60>, (BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy),), (28,))
# id:  001706238400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (29,))
# id:  001706239600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d7f0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (30,))
# id:  001706271399.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78ce48>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (31,))
# id:  001706273385.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79de10>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (32,))
# id:  001706273792.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781e10>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (33,))
# id:  001706274698.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558588>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (34,))
# id:  001706274970.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558748>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (35,))
# id:  001706275985.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c780>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (36,))
# id:  001706276300.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (37,))
# id:  001706276301.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6ba8>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (38,))
# id:  017062110512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a62e8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (39,))
# id:  017062111312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7950b8>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (40,))
# id:  017062112512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795860>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (41,))
# id:  017062114312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5587b8>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (42,))
# id:  017062115512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (43,))
# id:  017062117112.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558710>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (44,))
# id:  017062120464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5587b8>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (45,))
# id:  017062121664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79dcc0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (46,))
# id:  017062123264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558fd0>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (47,))
# id:  017062124664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c828>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (48,))
# id:  017062125864.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781f60>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (49,))
# id:  017062127064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c8d0>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (50,))
# id:  017062128464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c828>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (51,))
# id:  017062129664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558d68>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (52,))
# id:  017062130864.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795ac8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (53,))
# id:  017062132064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6a58>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (54,))
# id:  017062133264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6748>, (BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy),), (55,))
# id:  017062134464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d320>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (56,))
# id:  017062135864.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6a58>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (57,))
# id:  017062137064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7950f0>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (58,))
# id:  017062138264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78ca20>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (59,))
# id:  017062139464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6e10>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (60,))
# id:  017062140664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795710>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (61,))
# id:  017062142064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7956a0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (62,))
# id:  017062143264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (63,))
# id:  017062144464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5582b0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (64,))
# id:  017062147868.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c8d0>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (65,))
# id:  017062149068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558438>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (66,))
# id:  017062150068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558d68>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (67,))
# id:  017062151268.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cd68>, (BoxList(num_boxes=30, image_width=1333, image_height=750, mode=xyxy),), (68,))
# id:  017062152268.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=38, image_width=1333, image_height=750, mode=xyxy),), (69,))
# id:  017062153468.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558908>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (70,))
# id:  017062155068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (71,))
# id:  017062156268.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d320>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (72,))
# id:  017062157068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795860>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (73,))
# id:  017062158468.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79da58>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (74,))
# id:  017062159468.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (75,))
# id:  017062160535.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78ca20>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (76,))
# id:  017062161135.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6c88>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (77,))
# id:  017062162535.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7956a0>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (78,))
# id:  017062210600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795390>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (79,))
# id:  017062211800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558c50>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (80,))
# id:  017062213000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb668>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (81,))
# id:  017062214200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78ca20>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (82,))
# id:  017062215400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cbe0>, (BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy),), (83,))
# id:  017062216400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cbdd8>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (84,))
# id:  017062217600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb358>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (85,))
# id:  017062218800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b89e8>, (BoxList(num_boxes=30, image_width=1333, image_height=750, mode=xyxy),), (86,))
# id:  017062220000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7959e8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (87,))
# id:  017062221200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79dc50>, (BoxList(num_boxes=34, image_width=1333, image_height=750, mode=xyxy),), (88,))
# id:  017062222400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8710>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (89,))
# id:  017062223600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cbe0>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (90,))
# id:  017062224800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c400>, (BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy),), (91,))
# id:  017062226000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79db00>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (92,))
# id:  017062227200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79dcc0>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (93,))
# id:  017062228400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c518>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (94,))
# id:  017062229600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cda0>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (95,))
# id:  017062230800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d898>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (96,))
# id:  017062232000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795cf8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (97,))
# id:  017062232195.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795240>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (98,))
# id:  017062233200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c128>, (BoxList(num_boxes=30, image_width=1333, image_height=750, mode=xyxy),), (99,))
# id:  017062234400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6c50>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (100,))
# id:  017062235600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d390>, (BoxList(num_boxes=38, image_width=1333, image_height=750, mode=xyxy),), (101,))
# id:  017062236800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb278>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (102,))
# id:  017062238000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb550>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (103,))
# id:  017062238291.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c0f0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (104,))
# id:  017062239200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (105,))
# id:  017062240400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558710>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (106,))
# id:  017062241600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79dc88>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (107,))
# id:  017062242800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558358>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (108,))
# id:  017062244000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5589b0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (109,))
# id:  017062244925.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558358>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (110,))
# id:  017062245200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79dd68>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (111,))
# id:  017062246400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cba20>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (112,))
# id:  017062248800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558518>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (113,))
# id:  017062251200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79df60>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (114,))
# id:  017062252400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5584e0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (115,))
# id:  017062253586.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cbb70>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (116,))
# id:  017062253600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (117,))
# id:  017062254800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d4e0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (118,))
# id:  017062257200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cc88>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (119,))
# id:  017062258400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb908>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (120,))
# id:  017062259600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb128>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (121,))
# id:  017062260800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb5c0>, (BoxList(num_boxes=42, image_width=1333, image_height=750, mode=xyxy),), (122,))
# id:  017062310800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78cf98>, (BoxList(num_boxes=58, image_width=1333, image_height=750, mode=xyxy),), (123,))
# id:  017062312000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb9b0>, (BoxList(num_boxes=54, image_width=1333, image_height=750, mode=xyxy),), (124,))
# id:  017062313200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb5c0>, (BoxList(num_boxes=34, image_width=1333, image_height=750, mode=xyxy),), (125,))
# id:  017062314400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6c88>, (BoxList(num_boxes=56, image_width=1333, image_height=750, mode=xyxy),), (126,))
# id:  017062315600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d978>, (BoxList(num_boxes=58, image_width=1333, image_height=750, mode=xyxy),), (127,))
# id:  017062316800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd78c8d0>, (BoxList(num_boxes=50, image_width=1333, image_height=750, mode=xyxy),), (128,))
# id:  017062318000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558cc0>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (129,))
# id:  017062321600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795dd8>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (130,))
# id:  017062322800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7950f0>, (BoxList(num_boxes=38, image_width=1333, image_height=750, mode=xyxy),), (131,))
# id:  017062324000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795dd8>, (BoxList(num_boxes=46, image_width=1333, image_height=750, mode=xyxy),), (132,))
# id:  017062325200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1f60>, (BoxList(num_boxes=44, image_width=1333, image_height=750, mode=xyxy),), (133,))
# id:  017062326400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1cf8>, (BoxList(num_boxes=52, image_width=1333, image_height=750, mode=xyxy),), (134,))
# id:  017062327600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fc943358>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (0,))
# id:  000001706210.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d128>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (1,))
# id:  000001706220.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781eb8>, (BoxList(num_boxes=48, image_width=1333, image_height=750, mode=xyxy),), (2,))
# id:  000001706230.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8358>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (3,))
# id:  001706211200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fc943358>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (4,))
# id:  001706211912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795860>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (5,))
# id:  001706212400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6400>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (6,))
# id:  001706212912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6358>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (7,))
# id:  001706213912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a62e8>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (8,))
# id:  001706214912.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1518>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (9,))
# id:  001706216112.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1a20>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (10,))
# id:  001706217312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8f28>, (BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy),), (11,))
# id:  001706218312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0208>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (12,))
# id:  001706219512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1518>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (13,))
# id:  001706221200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8390>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (14,))
# id:  001706222400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0c50>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (15,))
# id:  001706223600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c12e8>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (16,))
# id:  001706224800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c19e8>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (17,))
# id:  001706226000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8940>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (18,))
# id:  001706227200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795cc0>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (19,))
# id:  001706228200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1240>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (20,))
# id:  001706229244.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558780>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (21,))
# id:  001706229257.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558860>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (22,))
# id:  001706229400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0320>, (BoxList(num_boxes=46, image_width=1333, image_height=750, mode=xyxy),), (23,))
# id:  001706231200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558860>, (BoxList(num_boxes=48, image_width=1333, image_height=750, mode=xyxy),), (24,))
# id:  001706232200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5587f0>, (BoxList(num_boxes=40, image_width=1333, image_height=750, mode=xyxy),), (25,))
# id:  001706234600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1550>, (BoxList(num_boxes=40, image_width=1333, image_height=750, mode=xyxy),), (26,))
# id:  001706235800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5587f0>, (BoxList(num_boxes=56, image_width=1333, image_height=750, mode=xyxy),), (27,))
# id:  001706237000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b87b8>, (BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy),), (28,))
# id:  001706238400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558908>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (29,))
# id:  001706239600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6630>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (30,))
# id:  001706271399.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6d68>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (31,))
# id:  001706273385.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558358>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (32,))
# id:  001706273792.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6f60>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (33,))
# id:  001706274698.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6b00>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (34,))
# id:  001706274970.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6940>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (35,))
# id:  001706275985.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d9b0>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (36,))
# id:  001706276300.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (37,))
# id:  001706276301.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6cc0>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (38,))
# id:  017062110512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558710>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (39,))
# id:  017062111312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558c88>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (40,))
# id:  017062112512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a62b0>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (41,))
# id:  017062114312.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795198>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (42,))
# id:  017062115512.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fc943358>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (43,))
# id:  017062117112.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558630>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (44,))
# id:  017062120464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d128>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (45,))
# id:  017062121664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0dd8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (46,))
# id:  017062123264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0518>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (47,))
# id:  017062124664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795b70>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (48,))
# id:  017062125864.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c12e8>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (49,))
# id:  017062127064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d668>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (50,))
# id:  017062128464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1908>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (51,))
# id:  017062129664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558da0>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (52,))
# id:  017062130864.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558358>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (53,))
# id:  017062132064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c10b8>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (54,))
# id:  017062133264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795710>, (BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy),), (55,))
# id:  017062134464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5583c8>, (BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy),), (56,))
# id:  017062135864.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7956a0>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (57,))
# id:  017062137064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1908>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (58,))
# id:  017062138264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6160>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (59,))
# id:  017062139464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7950f0>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (60,))
# id:  017062140664.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1240>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (61,))
# id:  017062142064.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a62e8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (62,))
# id:  017062143264.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6160>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (63,))
# id:  017062144464.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79dfd0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (64,))
# id:  017062147868.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79df98>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (65,))
# id:  017062149068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c16d8>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (66,))
# id:  017062150068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6748>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (67,))
# id:  017062151268.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558f98>, (BoxList(num_boxes=30, image_width=1333, image_height=750, mode=xyxy),), (68,))
# id:  017062152268.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558b00>, (BoxList(num_boxes=38, image_width=1333, image_height=750, mode=xyxy),), (69,))
# id:  017062153468.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781e10>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (70,))
# id:  017062155068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6f60>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (71,))
# id:  017062156268.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b03c8>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (72,))
# id:  017062157068.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781f60>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (73,))
# id:  017062158468.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6e10>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (74,))
# id:  017062159468.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0828>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (75,))
# id:  017062160535.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0908>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (76,))
# id:  017062161135.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79df60>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (77,))
# id:  017062162535.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d978>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (78,))
# id:  017062210600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1908>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (79,))
# id:  017062211800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6748>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (80,))
# id:  017062213000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7959e8>, (BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy),), (81,))
# id:  017062214200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1c50>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (82,))
# id:  017062215400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d748>, (BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy),), (83,))
# id:  017062216400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781eb8>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (84,))
# id:  017062217600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5586a0>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (85,))
# id:  017062218800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d978>, (BoxList(num_boxes=30, image_width=1333, image_height=750, mode=xyxy),), (86,))
# id:  017062220000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7952e8>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (87,))
# id:  017062221200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=34, image_width=1333, image_height=750, mode=xyxy),), (88,))
# id:  017062222400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6400>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (89,))
# id:  017062223600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558860>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (90,))
# id:  017062224800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558b00>, (BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy),), (91,))
# id:  017062226000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781e10>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (92,))
# id:  017062227200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c10b8>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (93,))
# id:  017062228400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0470>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (94,))
# id:  017062229600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c13c8>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (95,))
# id:  017062230800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0f98>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (96,))
# id:  017062232000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795c18>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (97,))
# id:  017062232195.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1630>, (BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy),), (98,))
# id:  017062233200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781da0>, (BoxList(num_boxes=30, image_width=1333, image_height=750, mode=xyxy),), (99,))
# id:  017062234400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b05c0>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (100,))
# id:  017062235600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795e80>, (BoxList(num_boxes=38, image_width=1333, image_height=750, mode=xyxy),), (101,))
# id:  017062236800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781f60>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (102,))
# id:  017062238000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0630>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (103,))
# id:  017062238291.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1c50>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (104,))
# id:  017062239200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795d30>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (105,))
# id:  017062240400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1908>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (106,))
# id:  017062241600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558b70>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (107,))
# id:  017062242800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795cc0>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (108,))
# id:  017062244000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6668>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (109,))
# id:  017062244925.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6b00>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (110,))
# id:  017062245200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c10b8>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (111,))
# id:  017062246400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781e10>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (112,))
# id:  017062248800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0be0>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (113,))
# id:  017062251200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558358>, (BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy),), (114,))
# id:  017062252400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558940>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (115,))
# id:  017062253586.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd558ba8>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (116,))
# id:  017062253600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6978>, (BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy),), (117,))
# id:  017062254800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1860>, (BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy),), (118,))
# id:  017062257200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0518>, (BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy),), (119,))
# id:  017062258400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0470>, (BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy),), (120,))
# id:  017062259600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5585f8>, (BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy),), (121,))
# id:  017062260800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6550>, (BoxList(num_boxes=42, image_width=1333, image_height=750, mode=xyxy),), (122,))
# id:  017062310800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79df98>, (BoxList(num_boxes=58, image_width=1333, image_height=750, mode=xyxy),), (123,))
# id:  017062312000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb470>, (BoxList(num_boxes=54, image_width=1333, image_height=750, mode=xyxy),), (124,))
# id:  017062313200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7cb9e8>, (BoxList(num_boxes=34, image_width=1333, image_height=750, mode=xyxy),), (125,))
# id:  017062314400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd79d588>, (BoxList(num_boxes=56, image_width=1333, image_height=750, mode=xyxy),), (126,))
# id:  017062315600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5586a0>, (BoxList(num_boxes=58, image_width=1333, image_height=750, mode=xyxy),), (127,))
# id:  017062316800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7a6e10>, (BoxList(num_boxes=50, image_width=1333, image_height=750, mode=xyxy),), (128,))
# id:  017062318000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b0fd0>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (129,))
# id:  017062321600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd795390>, (BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy),), (130,))
# id:  017062322800.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd781dd8>, (BoxList(num_boxes=38, image_width=1333, image_height=750, mode=xyxy),), (131,))
# id:  017062324000.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8ac8>, (BoxList(num_boxes=46, image_width=1333, image_height=750, mode=xyxy),), (132,))
# id:  017062325200.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7c1470>, (BoxList(num_boxes=44, image_width=1333, image_height=750, mode=xyxy),), (133,))
# id:  017062326400.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd5584e0>, (BoxList(num_boxes=52, image_width=1333, image_height=750, mode=xyxy),), (134,))
# id:  017062327600.jpg
# next
# (<maskrcnn_benchmark.structures.image_list.ImageList object at 0x2b03fd7b8c50>, (BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy),), (0,))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-27ff32e19a7b> in <module>
#       2 for i, d in enumerate(data_loader): # or i, image in enumerate(dataset)
#       3     print(d)
# ----> 4     print("id: ", dataset.get_img_info(i)["file_name"] )
#       5     print("next")
#
# /share/ctn/users/bsb2144/directpose/maskrcnn_benchmark/data/datasets/concat_dataset.py in get_img_info(self, idx)
#      21     def get_img_info(self, idx):
#      22         dataset_idx, sample_idx = self.get_idxs(idx)
# ---> 23         return self.datasets[dataset_idx].get_img_info(sample_idx)
#
# IndexError: list index out of range

# %%
print(len(data_loader))
#print(dataset.id_to_img_map)
#for i, d in enumerate(data_loader): # or i, image in enumerate(dataset)
 #   print(d)
  #  print("id: ", dataset.get_img_info(0)["file_name"] )
    #print("next")
i =0
c_losses = []


for iteration, (images, targets, _) in enumerate(data_loader, i):
        i = i + 1
        #print(images)
        #print([targets[0]])
        t = targets[0].to("cuda")
        tt = [t]
        images = images.to("cuda")
        ##tt = tt.cuda()
        ##predictions, tps, hm_res, stride, hms, targets, c_loss = coco_demo.run_on_opencv_image(images, tt)
        c_loss = coco_demo.run_on_opencv_image(images, tt)
        c_losses.append(c_loss)
        print("c loss: ", c_loss)
        print("next")
# Out:
# 300
# In hm proc target
# CUDAA
# summm:  tensor(3.0121, device='cuda:0')
# well heres the loss ay:  tensor(0.0538, device='cuda:0')
# now prop
# [BoxList(num_boxes=13, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor
device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2224, device='cuda:0')
# c loss:  tensor(0.2224, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(0.8225, device='cuda:0')
# well heres the loss ay:  tensor(0.0284, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(11.5416, device='cuda:0')
# well heres the loss ay:  tensor(0.3497, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3497, device='cuda:0')
# c loss:  tensor(0.3497, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.5108, device='cuda:0')
# well heres the loss ay:  tensor(0.0755, device='cuda:0')
# now prop
# [BoxList(num_boxes=5, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(8.5576, device='cuda:0')
# well heres the loss ay:  tensor(0.3566, device='cuda:0')
# raw res:
# [BoxList(num_boxes=5, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3566, device='cuda:0')
# c loss:  tensor(0.3566, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.6548, device='cuda:0')
# well heres the loss ay:  tensor(0.0914, device='cuda:0')
# now prop
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(6.3641, device='cuda:0')
# well heres the loss ay:  tensor(0.1591, device='cuda:0')
# raw res:
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1591, device='cuda:0')
# c loss:  tensor(0.1591, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.8740, device='cuda:0')
# well heres the loss ay:  tensor(0.0367, device='cuda:0')
# now prop
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(19.5607, device='cuda:0')
# well heres the loss ay:  tensor(0.3556, device='cuda:0')
# raw res:
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3556, device='cuda:0')
# c loss:  tensor(0.3556, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.4376, device='cuda:0')
# well heres the loss ay:  tensor(0.0496, device='cuda:0')
# now prop
# [BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(4.9755, device='cuda:0')
# well heres the loss ay:  tensor(0.1659, device='cuda:0')
# raw res:
# [BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1659, device='cuda:0')
# c loss:  tensor(0.1659, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.1842, device='cuda:0')
# well heres the loss ay:  tensor(0.0569, device='cuda:0')
# now prop
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(12.4986, device='cuda:0')
# well heres the loss ay:  tensor(0.2083, device='cuda:0')
# raw res:
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2083, device='cuda:0')
# c loss:  tensor(0.2083, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.7626, device='cuda:0')
# well heres the loss ay:  tensor(0.0441, device='cuda:0')
# now prop
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(2.9704, device='cuda:0')
# well heres the loss ay:  tensor(0.0743, device='cuda:0')
# raw res:
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.0743, device='cuda:0')
# c loss:  tensor(0.0743, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.0540, device='cuda:0')
# well heres the loss ay:  tensor(0.0456, device='cuda:0')
# now prop
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(7.6988, device='cuda:0')
# well heres the loss ay:  tensor(0.1711, device='cuda:0')
# raw res:
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1711, device='cuda:0')
# c loss:  tensor(0.1711, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.5093, device='cuda:0')
# well heres the loss ay:  tensor(0.0290, device='cuda:0')
# now prop
# [BoxList(num_boxes=17, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(37.2214, device='cuda:0')
# well heres the loss ay:  tensor(0.5170, device='cuda:0')
# raw res:
# [BoxList(num_boxes=17, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.5170, device='cuda:0')
# c loss:  tensor(0.5170, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.2036, device='cuda:0')
# well heres the loss ay:  tensor(0.0801, device='cuda:0')
# now prop
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(10.1657, device='cuda:0')
# well heres the loss ay:  tensor(0.2541, device='cuda:0')
# raw res:
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2541, device='cuda:0')
# c loss:  tensor(0.2541, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.8130, device='cuda:0')
# well heres the loss ay:  tensor(0.0355, device='cuda:0')
# now prop
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(18.6082, device='cuda:0')
# well heres the loss ay:  tensor(0.3208, device='cuda:0')
# raw res:
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3208, device='cuda:0')
# c loss:  tensor(0.3208, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.7204, device='cuda:0')
# well heres the loss ay:  tensor(0.0465, device='cuda:0')
# now prop
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(11.8619, device='cuda:0')
# well heres the loss ay:  tensor(0.2965, device='cuda:0')
# raw res:
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2965, device='cuda:0')
# c loss:  tensor(0.2965, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.2911, device='cuda:0')
# well heres the loss ay:  tensor(0.0323, device='cuda:0')
# now prop
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.6149, device='cuda:0')
# well heres the loss ay:  tensor(0.3470, device='cuda:0')
# raw res:
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3470, device='cuda:0')
# c loss:  tensor(0.3470, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.5535, device='cuda:0')
# well heres the loss ay:  tensor(0.0518, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(8.0954, device='cuda:0')
# well heres the loss ay:  tensor(0.2381, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2381, device='cuda:0')
# c loss:  tensor(0.2381, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.9401, device='cuda:0')
# well heres the loss ay:  tensor(0.0404, device='cuda:0')
# now prop
# [BoxList(num_boxes=13, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.7867, device='cuda:0')
# well heres the loss ay:  tensor(0.2870, device='cuda:0')
# raw res:
# [BoxList(num_boxes=13, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2870, device='cuda:0')
# c loss:  tensor(0.2870, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.4238, device='cuda:0')
# well heres the loss ay:  tensor(0.0331, device='cuda:0')
# now prop
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.8224, device='cuda:0')
# well heres the loss ay:  tensor(0.3164, device='cuda:0')
# raw res:
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3164, device='cuda:0')
# c loss:  tensor(0.3164, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.3301, device='cuda:0')
# well heres the loss ay:  tensor(0.0583, device='cuda:0')
# now prop
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(10.6063, device='cuda:0')
# well heres the loss ay:  tensor(0.2411, device='cuda:0')
# raw res:
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2411, device='cuda:0')
# c loss:  tensor(0.2411, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.6853, device='cuda:0')
# well heres the loss ay:  tensor(0.0674, device='cuda:0')
# now prop
# [BoxList(num_boxes=5, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(2.8375, device='cuda:0')
# well heres the loss ay:  tensor(0.1135, device='cuda:0')
# raw res:
# [BoxList(num_boxes=5, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1135, device='cuda:0')
# c loss:  tensor(0.1135, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(0.5921, device='cuda:0')
# well heres the loss ay:  tensor(0.0296, device='cuda:0')
# now prop
# [BoxList(num_boxes=4, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(2.9372, device='cuda:0')
# well heres the loss ay:  tensor(0.1469, device='cuda:0')
# raw res:
# [BoxList(num_boxes=4, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1469, device='cuda:0')
# c loss:  tensor(0.1469, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(0.3196, device='cuda:0')
# well heres the loss ay:  tensor(0.0145, device='cuda:0')
# now prop
# [BoxList(num_boxes=5, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(5.3270, device='cuda:0')
# well heres the loss ay:  tensor(0.2220, device='cuda:0')
# raw res:
# [BoxList(num_boxes=5, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2220, device='cuda:0')
# c loss:  tensor(0.2220, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.2145, device='cuda:0')
# well heres the loss ay:  tensor(0.0434, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.0492, device='cuda:0')
# well heres the loss ay:  tensor(0.4300, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4300, device='cuda:0')
# c loss:  tensor(0.4300, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.6579, device='cuda:0')
# well heres the loss ay:  tensor(0.0592, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(16.3590, device='cuda:0')
# well heres the loss ay:  tensor(0.4674, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4674, device='cuda:0')
# c loss:  tensor(0.4674, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.4160, device='cuda:0')
# well heres the loss ay:  tensor(0.0403, device='cuda:0')
# now prop
# [BoxList(num_boxes=13, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(13.7377, device='cuda:0')
# well heres the loss ay:  tensor(0.2147, device='cuda:0')
# raw res:
# [BoxList(num_boxes=13, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2147, device='cuda:0')
# c loss:  tensor(0.2147, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.7649, device='cuda:0')
# well heres the loss ay:  tensor(0.0512, device='cuda:0')
# now prop
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(11.6288, device='cuda:0')
# well heres the loss ay:  tensor(0.2114, device='cuda:0')
# raw res:
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2114, device='cuda:0')
# c loss:  tensor(0.2114, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.4537, device='cuda:0')
# well heres the loss ay:  tensor(0.0744, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(8.0246, device='cuda:0')
# well heres the loss ay:  tensor(0.2293, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.
device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(13.2388, device='cuda:0')
# well heres the loss ay:  tensor(0.3783, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3783, device='cuda:0')
# c loss:  tensor(0.3783, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(0.8530, device='cuda:0')
# well heres the loss ay:  tensor(0.0224, device='cuda:0')
# now prop
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(5.6525, device='cuda:0')
# well heres the loss ay:  tensor(0.1413, device='cuda:0')
# raw res:
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1413, device='cuda:0')
# c loss:  tensor(0.1413, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(0.9074, device='cuda:0')
# well heres the loss ay:  tensor(0.0336, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(12.7447, device='cuda:0')
# well heres the loss ay:  tensor(0.3641, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3641, device='cuda:0')
# c loss:  tensor(0.3641, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.6865, device='cuda:0')
# well heres the loss ay:  tensor(0.0413, device='cuda:0')
# now prop
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(16.4527, device='cuda:0')
# well heres the loss ay:  tensor(0.2350, device='cuda:0')
# raw res:
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2350, device='cuda:0')
# c loss:  tensor(0.2350, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.5720, device='cuda:0')
# well heres the loss ay:  tensor(0.0518, device='cuda:0')
# now prop
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.0503, device='cuda:0')
# well heres the loss ay:  tensor(0.2090, device='cuda:0')
# raw res:
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2090, device='cuda:0')
# c loss:  tensor(0.2090, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.6253, device='cuda:0')
# well heres the loss ay:  tensor(0.0525, device='cuda:0')
# now prop
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(10.2916, device='cuda:0')
# well heres the loss ay:  tensor(0.1410, device='cuda:0')
# raw res:
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1410, device='cuda:0')
# c loss:  tensor(0.1410, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.2482, device='cuda:0')
# well heres the loss ay:  tensor(0.0464, device='cuda:0')
# now prop
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.2534, device='cuda:0')
# well heres the loss ay:  tensor(0.2179, device='cuda:0')
# raw res:
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2179, device='cuda:0')
# c loss:  tensor(0.2179, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.4011, device='cuda:0')
# well heres the loss ay:  tensor(0.0466, device='cuda:0')
# now prop
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(20.6287, device='cuda:0')
# well heres the loss ay:  tensor(0.2579, device='cuda:0')
# raw res:
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2579, device='cuda:0')
# c loss:  tensor(0.2579, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(4.6668, device='cuda:0')
# well heres the loss ay:  tensor(0.0562, device='cuda:0')
# now prop
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(19.0832, device='cuda:0')
# well heres the loss ay:  tensor(0.2245, device='cuda:0')
# raw res:
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2245, device='cuda:0')
# c loss:  tensor(0.2245, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.3215, device='cuda:0')
# well heres the loss ay:  tensor(0.0298, device='cuda:0')
# now prop
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(12.9905, device='cuda:0')
# well heres the loss ay:  tensor(0.1624, device='cuda:0')
# raw res:
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1624, device='cuda:0')
# c loss:  tensor(0.1624, device='cuda:0')
# next
# In hm proc target
# CUDAA
# ...
# raw res:
# [BoxList(num_boxes=11, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2940, device='cuda:0')
# c loss:  tensor(0.2940, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(6.4360, device='cuda:0')
# well heres the loss ay:  tensor(0.0555, device='cuda:0')
# now prop
# [BoxList(num_boxes=29, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=48, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(64.8880, device='cuda:0')
# well heres the loss ay:  tensor(0.4736, device='cuda:0')
# raw res:
# [BoxList(num_boxes=29, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4736, device='cuda:0')
# c loss:  tensor(0.4736, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.5693, device='cuda:0')
# well heres the loss ay:  tensor(0.0714, device='cuda:0')
# now prop
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(22.8381, device='cuda:0')
# well heres the loss ay:  tensor(0.3938, device='cuda:0')
# raw res:
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3938, device='cuda:0')
# c loss:  tensor(0.3938, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.6518, device='cuda:0')
# well heres the loss ay:  tensor(0.0472, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(6.8013, device='cuda:0')
# well heres the loss ay:  tensor(0.1943, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1943, device='cuda:0')
# c loss:  tensor(0.1943, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.7710, device='cuda:0')
# well heres the loss ay:  tensor(0.0589, device='cuda:0')
# now prop
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(25.3466, device='cuda:0')
# well heres the loss ay:  tensor(0.3472, device='cuda:0')
# raw res:
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3472, device='cuda:0')
# c loss:  tensor(0.3472, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.5569, device='cuda:0')
# well heres the loss ay:  tensor(0.0458, device='cuda:0')
# now prop
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(9.7708, device='cuda:0')
# well heres the loss ay:  tensor(0.2443, device='cuda:0')
# raw res:
# [BoxList(num_boxes=8, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2443, device='cuda:0')
# c loss:  tensor(0.2443, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.4904, device='cuda:0')
# well heres the loss ay:  tensor(0.0655, device='cuda:0')
# now prop
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.7958, device='cuda:0')
# well heres the loss ay:  tensor(0.3510, device='cuda:0')
# raw res:
# [BoxList(num_boxes=9, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3510, device='cuda:0')
# c loss:  tensor(0.3510, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.5931, device='cuda:0')
# well heres the loss ay:  tensor(0.0370, device='cuda:0')
# now prop
# [BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(14.2470, device='cuda:0')
# well heres the loss ay:  tensor(0.2849, device='cuda:0')
# raw res:
# [BoxList(num_boxes=10, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2849, device='cuda:0')
# c loss:  tensor(0.2849, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.5921, device='cuda:0')
# well heres the loss ay:  tensor(0.0569, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.7239, device='cuda:0')
# well heres the loss ay:  tensor(0.4493, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4493, device='cuda:0')
# c loss:  tensor(0.4493, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.1785, device='cuda:0')
# well heres the loss ay:  tensor(0.0393, device='cuda:0')
# now prop
# [BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(4.5737, device='cuda:0')
# well heres the loss ay:  tensor(0.1525, device='cuda:0')
# raw res:
# [BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1525, device='cuda:0')
# c loss:  tensor(0.1525, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.0109, device='cuda:0')
# well heres the loss ay:  tensor(0.0674, device='cuda:0')
# now prop
# [BoxList(num_boxes=4, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=6, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(3.5881, device='cuda:0')
# well heres the loss ay:  tensor(0.1794, device='cuda:0')
# raw res:
# [BoxList(num_boxes=4, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1794, device='cuda:0')
# c loss:  tensor(0.1794, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(0.6354, device='cuda:0')
# well heres the loss ay:  tensor(0.0199, device='cuda:0')
# now prop
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(16.5666, device='cuda:0')
# well heres the loss ay:  tensor(0.4733, device='cuda:0')
# raw res:
# [BoxList(num_boxes=7, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4733, device='cuda:0')
# c loss:  tensor(0.4733, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(4.4638, device='cuda:0')
# well heres the loss ay:  tensor(0.0783, device='cuda:0')
# now prop
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(9.1493, device='cuda:0')
# well heres the loss ay:  tensor(0.1551, device='cuda:0')
# raw res:
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1551, device='cuda:0')
# c loss:  tensor(0.1551, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(4.3320, device='cuda:0')
# well heres the loss ay:  tensor(0.0647, device='cuda:0')
# now prop
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(25.9292, device='cuda:0')
# well heres the loss ay:  tensor(0.3457, device='cuda:0')
# raw res:
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3457, device='cuda:0')
# c loss:  tensor(0.3457, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.8852, device='cuda:0')
# well heres the loss ay:  tensor(0.0607, device='cuda:0')
# now prop
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(15.3481, device='cuda:0')
# well heres the loss ay:  tensor(0.2257, device='cuda:0')
# raw res:
# [BoxList(num_boxes=14, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2257, device='cuda:0')
# c loss:  tensor(0.2257, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.5696, device='cuda:0')
# well heres the loss ay:  tensor(0.0459, device='cuda:0')
# now prop
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(10.3381, device='cuda:0')
# well heres the loss ay:  tensor(0.1782, device='cuda:0')
# raw res:
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1782, device='cuda:0')
# c loss:  tensor(0.1782, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.6600, device='cuda:0')
# well heres the loss ay:  tensor(0.0436, device='cuda:0')
# now prop
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=26, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(33.7351, device='cuda:0')
# well heres the loss ay:  tensor(0.4751, device='cuda:0')
# raw res:
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4751, device='cuda:0')
# c loss:  tensor(0.4751, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.4720, device='cuda:0')
# well heres the loss ay:  tensor(0.0325, device='cuda:0')
# now prop
# [BoxList(num_boxes=17, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=32, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(16.7827, device='cuda:0')
# well heres the loss ay:  tensor(0.1998, device='cuda:0')
# raw res:
# [BoxList(num_boxes=17, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.1998, device='cuda:0')
# c loss:  tensor(0.1998, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.9368, device='cuda:0')
# well heres the loss ay:  tensor(0.0489, device='cuda:0')
# now prop
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(12.4041, device='cuda:0')
# well heres the loss ay:  tensor(0.2067, device='cuda:0')
# raw res:
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2067, device='cuda:0')
# c loss:  tensor(0.2067, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.6622, device='cuda:0')
# well heres the loss ay:  tensor(0.0475, device='cuda:0')
# now prop
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(26.9484, device='cuda:0')
# well heres the loss ay:  tensor(0.3963, device='cuda:0')
# raw res:
# [BoxList(num_boxes=16, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3963, device='cuda:0')
# c loss:  tensor(0.3963, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(2.2335, device='cuda:0')
# well heres the loss ay:  tensor(0.0447, device='cuda:0')
# now prop
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=22, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(39.0359, device='cuda:0')
# well heres the loss ay:  tensor(0.5915, device='cuda:0')
# raw res:
# [BoxList(num_boxes=15, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.5915, device='cuda:0')
# c loss:  tensor(0.5915, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(1.8236, device='cuda:0')
# well heres the loss ay:  tensor(0.0380, device='cuda:0')
# now prop
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=20, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(16.6421, device='cuda:0')
# well heres the loss ay:  tensor(0.2774, device='cuda:0')
# raw res:
# [BoxList(num_boxes=12, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2774, device='cuda:0')
# c loss:  tensor(0.2774, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(10.3604, device='cuda:0')
# well heres the loss ay:  tensor(0.0968, device='cuda:0')
# now prop
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=46, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(55.5392, device='cuda:0')
# well heres the loss ay:  tensor(0.4628, device='cuda:0')
# raw res:
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4628, device='cuda:0')
# c loss:  tensor(0.4628, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(6.5441, device='cuda:0')
# well heres the loss ay:  tensor(0.0564, device='cuda:0')
# now prop
# [BoxList(num_boxes=25, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=48, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(42.8340, device='cuda:0')
# well heres the loss ay:  tensor(0.3454, device='cuda:0')
# raw res:
# [BoxList(num_boxes=25, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3454, device='cuda:0')
# c loss:  tensor(0.3454, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(4.9385, device='cuda:0')
# well heres the loss ay:  tensor(0.0555, device='cuda:0')
# now prop
# [BoxList(num_boxes=25, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=40, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(51.0325, device='cuda:0')
# well heres the loss ay:  tensor(0.4438, device='cuda:0')
# raw res:
# [BoxList(num_boxes=25, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.4438, device='cuda:0')
# c loss:  tensor(0.4438, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(4.4457, device='cuda:0')
# well heres the loss ay:  tensor(0.0468, device='cuda:0')
# now prop
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=40, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(37.1116, device='cuda:0')
# well heres the loss ay:  tensor(0.3227, device='cuda:0')
# raw res:
# [BoxList(num_boxes=24, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3227, device='cuda:0')
# c loss:  tensor(0.3227, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(7.8046, device='cuda:0')
# well heres the loss ay:  tensor(0.0582, device='cuda:0')
# now prop
# [BoxList(num_boxes=55, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=56, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(142.2032, device='cuda:0')
# well heres the loss ay:  tensor(0.6292, device='cuda:0')
# raw res:
# [BoxList(num_boxes=55, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.6292, device='cuda:0')
# c loss:  tensor(0.6292, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(5.0102, device='cuda:0')
# well heres the loss ay:  tensor(0.0569, device='cuda:0')
# now prop
# [BoxList(num_boxes=23, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=36, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(37.9632, device='cuda:0')
# well heres the loss ay:  tensor(0.3616, device='cuda:0')
# raw res:
# [BoxList(num_boxes=23, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.3616, device='cuda:0')
# c loss:  tensor(0.3616, device='cuda:0')
# next
# In hm proc target
# CUDAA
# summm:  tensor(3.9257, device='cuda:0')
# well heres the loss ay:  tensor(0.0595, device='cuda:0')
# now prop
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# [BoxList(num_boxes=28, image_width=1333, image_height=750, mode=xyxy)]
# R
# T
# In hm proc target
# CUDAA
# summm:  tensor(20.9476, device='cuda:0')
# well heres the loss ay:  tensor(0.2756, device='cuda:0')
# raw res:
# [BoxList(num_boxes=18, image_width=1333, image_height=750, mode=xyxy)]
# c loss:  tensor(0.2756, device='cuda:0')
# c loss:  tensor(0.2756, device='cuda:0')
# next

# %%
#print(c_losses)
print(len(c_losses))
print(c_losses[0])
print(c_losses[1])
print(c_losses[2])
print(c_losses[3])
print("brek")
print(c_losses[135])
print(c_losses[136])
print(c_losses[137])
print(c_losses[138])
# Out:
# 300
# tensor(0.2763, device='cuda:0')
# tensor(0.2940, device='cuda:0')
# tensor(0.4736, device='cuda:0')
# tensor(0.3938, device='cuda:0')
# brek
# tensor(0.2763, device='cuda:0')
# tensor(0.2940, device='cuda:0')
# tensor(0.4736, device='cuda:0')
# tensor(0.3938, device='cuda:0')

# %%
import numpy as np
cln = c_losses[0:135]
for i, item in enumerate(cln):
    cln[i] = item.item()
print(len(cln))
print(cln[0])
arr = np.array(cln)
max_ids = (arr.argsort()[-10:][::-1])
print(max_ids)
print(arr)

max_files = []
for ind in max_ids:
    file = dataset.get_img_info(ind)["file_name"]
    max_files.append(file)
    
print(max_files)
# Out:
# 135
# 0.27633175253868103
# [ 27 130  21  45 126 125  95 117 123 113]
# [0.27633175 0.29397923 0.4736352  0.39375964 0.19432341 0.34721315
#  0.24426924 0.35101739 0.28494015 0.44925448 0.15245706 0.17940643
#  0.47333118 0.15507245 0.34572208 0.20141257 0.17824273 0.47514278
#  0.19979414 0.20673577 0.39630058 0.54464656 0.27736783 0.46282676
#  0.34543511 0.46120581 0.32270923 0.62849116 0.36155391 0.25570202
#  0.33133888 0.21514937 0.3820298  0.23060238 0.3332907  0.18376429
#  0.22239308 0.34974605 0.35656747 0.15910214 0.35564882 0.16585128
#  0.20830955 0.07426106 0.17108485 0.51696342 0.25414357 0.32083032
#  0.2965475  0.34699827 0.23810092 0.28703016 0.31644782 0.2410531
#  0.1135014  0.14685927 0.22195974 0.42997715 0.46739954 0.21465223
#  0.21143317 0.22927436 0.24434948 0.42068031 0.31583226 0.21069203
#  0.42219606 0.36549044 0.37092587 0.30198488 0.25159973 0.1607825
#  0.29434827 0.23750739 0.3109366  0.37825164 0.14131318 0.3641353
#  0.23503879 0.20903222 0.14098056 0.21790557 0.25785819 0.22450837
#  0.16238157 0.22622971 0.26526853 0.17424278 0.18370152 0.22197914
#  0.33217061 0.23978436 0.35016063 0.34059888 0.19771214 0.50135708
#  0.28937933 0.26504761 0.17421158 0.31610328 0.33686393 0.3552644
#  0.22437613 0.33789474 0.30732861 0.27989534 0.38708538 0.31594014
#  0.33348674 0.3474136  0.14498079 0.29116607 0.21403335 0.47650689
#  0.19162324 0.10050012 0.25705546 0.50008136 0.44075158 0.15222102
#  0.23393534 0.31327388 0.23479517 0.49173743 0.43212804 0.50294173
#  0.51268828 0.38564244 0.43432128 0.37996224 0.55086404 0.41765985
#  0.27556333 0.28403652 0.25092837]
# ['001706237000.jpg', '017062322800.jpg', '001706229257.jpg', '017062121664.jpg', '017062315600.jpg', '017062314400.jpg', '017062230800.jpg', '017062254800.jpg', '017062312000.jpg', '017062251200.jpg']

# %%
import matplotlib.gridspec as gridspec

pad = 5
k=10
#print("test ig: ", test_images)
#print("test files: ", test_image_files)
rows = ["Heatmap Loss", "Original DP Loss", "Combo Loss", "Combo OG"]#"DP Predictions", "Combined Heatmap", "Combined Pred"]
cols = ["Heatmap", "Predictions"]
data_size = "250"
version = "0"
loss = "combined_from_standard_nw"

# %%
fig, axes = plt.subplots(1,3,figsize=(20,12),constrained_layout=True,gridspec_kw = {'wspace':.15, 'hspace':.15})
fig.subplots_adjust(wspace=.15, hspace=.000001)

title = 'Data Set: ' + data_size
fig.suptitle(title, y=.92)

config_file = "/home/bsb2144/directpose/configs/fcos/fcos_kps_ms_training_R_50_FPN_1x.yaml"

cfg.merge_from_file("/home/bsb2144/directpose/configs/fcos/fcos_kps_ms_training_R_50_FPN_1x.yaml")
cfg.merge_from_list(['DATALOADER.NUM_WORKERS', '2', \
                     'DATATYPE', 'bee', \
                     'OUTPUT_DIR', 'training_dir/' + data_size + '/' + loss +'/fcos_kps_ms_training_R_50_FPN_1x_bee1', \
                     'MODEL.WEIGHT', '/home/bsb2144/directpose/tools/training_dir/' + data_size + '/'+ loss +'/fcos_kps_ms_training_R_50_FPN_1x_bee/model_final.pth',\
                     'DATASETS.TEST', "('bee_val_cocostyle',)",\
                     'DATASETS.TRAIN', "('bee_train_cocostyle', )",\
                    ])

coco_demo = COCODemo(
            cfg,
            min_image_size=800,
            confidence_threshold=0.2,
)

c_losses = []

for idx, image in enumerate(test_images):
    predictions, tps, hm_res, stride, hms, targets, c_loss = coco_demo.run_on_opencv_image(image)
    c_losses.append(c_loss)
    
arr = np.array(c_losses)    
top_idxs = arr.argsort()[-k:][::-1]
top_images = np.array(test_image_files[top_idxs])

# %% [markdown]
# 1 of 8: 100/0/standard

# %%
sigmoid(0.37848875)
